# %%
# %matplotlib inline

# %% [markdown]
# PCA
#
# The first line turns on inline plotting, where plot graphics will appear in your notebook. Now use pandas to read dataframe.

# %%
import pandas as pd
import io
import requests
import numpy as np

# %% [markdown]
# Load dataset as 16x16 gray scale images of handwritten zip code 3, of total number 657111.
